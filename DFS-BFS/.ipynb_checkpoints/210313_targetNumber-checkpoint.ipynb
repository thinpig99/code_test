# %% [markdown]
# # 코딩 테스트 연습 > DFS/BFS > 타겟넘버

# %% [markdown]
# ## 문제 설명
# n개의 음이 아닌 정수가 있습니다. 이 수를 적절히 더하거나 빼서 타겟 넘버를 만들려고 합니다. 예를 들어 [1, 1, 1, 1, 1]로 숫자 3을 만들려면 다음 다섯 방법을 쓸 수 있습니다.

# %% [markdown]
# -1+1+1+1+1 = 3<br>
# +1-1+1+1+1 = 3<br>
# +1+1-1+1+1 = 3<br>
# +1+1+1-1+1 = 3<br>
# +1+1+1+1-1 = 3

# %% [markdown]
# 사용할 수 있는 숫자가 담긴 배열 numbers, 타겟 넘버 target이 매개변수로 주어질 때 숫자를 적절히 더하고 빼서 타겟 넘버를 만드는 방법의 수를 return 하도록 solution 함수를 작성해주세요.

# %% [markdown]
# ## 제한사항
# - 주어지는 숫자의 개수는 2개 이상 20개 이하입니다.
# - 각 숫자는 1 이상 50 이하인 자연수입니다.
# - 타겟 넘버는 1 이상 1000 이하인 자연수입니다.

# %% [markdown]
# ## 입출력 예
# |numbers|	target|	return|
# |---|---|---|
# |[1, 1, 1, 1, 1]|	3|	5|

# %%
def solution(numbers, target):
    answer = 0
    return answer

# %% [markdown]
# ### 아이디어

# %% [markdown]
# 배운대로 그래프로 접근을 해보자.
#
# 먼저 가장 첫번째 숫자로부터 시작한다. +가 있고, -가 있겠지.
# 그럼 그 다음 숫자를 +와 -로 나눠서 들어가겠지.
#
# 이런식으로 깊이를 계속 타고 내려가면서 일정 숫자가 완성되면 개수를 더하고,
#
# 스택에서 버린 다음 다음 노드로 가는 것이다.

# %%
import numpy as np

# %%
numbers = [1, 1, 1, 1, 1, 3, 3, 3, 3, 4, 4, 4]
target = 10

# %%
def dfs(graph, start, visited):
    global target
    global number
    global count

    # 아래 층의 왼쪽 방이 False 면 True로 바꾸고, 내려간다.
    if visited[start + 1][0] == False:
        visited[start + 1][0] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][0])
        # 층수를 낮춰준다.
        start += 1

        print("왼쪽 방 진입", "-"*70)
        print("방문 이력, visited: ", visited)
        print("현재 층, start: ", start)
        print("현재 number : ", number, np.sum(number))

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            print("지하 도착")
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1
                print("지하 도착, count는?: ", count)

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
            dfs(graph, start, visited)
        else:
            print("아래층으로")
            dfs(graph, start, visited)

    # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
    # 왼쪽만 True고 오른쪽은 False면
    elif visited[start + 1][1] == False:
        visited[start + 1][1] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][1])
        # 층수를 낮춰준다.
        start += 1

        print("오른쪽 방 진입", "-"*70)
        print("방문 이력, visited: ", visited)
        print("현재 층, start: ", start)
        print("현재 number : ", number, np.sum(number))

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            print("지하 도착")
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1
                print("지하 도착, count는?: ", count)

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
            dfs(graph, start, visited)
        else:
            print("아래층으로")
            dfs(graph, start, visited)

    # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
    # 올라갈 때는 자기 자신을 초기화하고 올라간다.
    else:
        print("양쪽이 모두 True 입니다!")
        print("현재 층: ", start)
        print("현재 이력: ", visited)
        print("현재 number : ", number, np.sum(number))

        # 옥상으로 올라갈 수 없을 때는 건물 밖을 나간다.
        if start == -1:
            print("옥상입니다.")
        else:
            # 위층으로 올라가기 전에 수를 빼준다.
            number.pop()

            # 올라가기 전 해당 층을 초기화 해준다.
            visited[start + 1][0] = False
            visited[start + 1][1] = False

            # 한 층 올라간다.
            start -= 1
            print("위로 진출", "**"*70)
            print("현재 이력, visited: ", visited)
            print("현재 층, start: ", start)
            print("현재 number : ", number)
            dfs(graph, start, visited)

    print("모든 경우를 수색했음.")
    print(count)

# %%
def solution(numbers, target):
    graph = []
    for i in numbers:
        graph.append([i, -i])
    visited = np.zeros((len(graph), 2), dtype=bool).tolist()

    start = -1 # 시작 노드의 층
    number = [] # target number
    count = 0 # target number count
    
    dfs(graph, start, visited)

    print(count)
    return count

# %%
solution(numbers, target)
# Out:
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1] -2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1] -1
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1] 0
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1] 1
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  4
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1] 2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  5
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3] 5
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  6
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3] 11
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3] 14
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4] 18
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, 4] 22
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, 4, 4] 26
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, 4, -4] 18
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, 4] 22
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, -4] 14
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, -4, 4] 18
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, -4, -4] 10
# 지하 도착
# 지하 도착, count는?:  1
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4, -4] 14
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, 4] 18
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4] 10
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, 4] 14
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, 4, 4] 18
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, 4, -4] 10
# 지하 도착
# 지하 도착, count는?:  2
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, 4] 14
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, -4] 6
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, -4, 4] 10
# 지하 도착
# 지하 도착, count는?:  3
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, -4, -4] 2
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4, -4] 6
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3, -4] 10
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3]
# 양쪽이 모두 True 입니다!
# 현재 층:  8
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, 3] 14
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4] 12
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, 4] 16
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, 4, 4] 20
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, 4, -4] 12
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, 4] 16
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, -4] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, -4, 4] 12
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, -4, -4] 4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4, -4] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, 4] 12
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4] 4
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, 4] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, 4, 4] 12
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, 4, -4] 4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, 4] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, -4] 0
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, -4, 4] 4
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, -4, -4] -4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4, -4] 0
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3, -4] 4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3]
# 양쪽이 모두 True 입니다!
# 현재 층:  8
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3, -3] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3]
# 양쪽이 모두 True 입니다!
# 현재 층:  7
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, 3] 11
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  6
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3] 5
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4] 12
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, 4] 16
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, 4, 4] 20
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, 4, -4] 12
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, 4] 16
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, -4] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, -4, 4] 12
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, -4, -4] 4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4, -4] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, 4] 12
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4] 4
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, 4] 8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, 4, 4] 12
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, 4, -4] 4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, 4] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, -4] 0
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, -4, 4] 4
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, -4, -4] -4
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4, -4] 0
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3, -4] 4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3]
# 양쪽이 모두 True 입니다!
# 현재 층:  8
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, 3] 8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3] 2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4] 6
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, 4] 10
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, 4, 4] 14
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, 4, -4] 6
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, 4] 10
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, -4] 2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, -4, 4] 6
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, -4, -4] -2
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4, -4] 2
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, 4] 6
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4] -2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, 4] 2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, 4, 4] 6
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, 4, -4] -2
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, 4] 2
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, -4] -6
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, -4, 4] -2
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, -4, -4] -10
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4, -4] -6
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, 1, 1, 1, 3, 3, -3, -3, -4] -2
# 위로 진출 ********************************************************************************************************************************************
# ...
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4, 4] 4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4, -4] -4
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4, -4, 4] 0
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4, -4, -4] -8
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4, -4] -4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, 4] 0
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4] -8
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, 4] -4
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, 4, 4] 0
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, 4, -4] -8
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, 4] -4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, -4] -12
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, -4, 4] -8
# 지하 도착
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, -4, -4] -16
# 지하 도착
# 양쪽이 모두 True 입니다!
# 현재 층:  10
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4, -4] -12
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4]
# 양쪽이 모두 True 입니다!
# 현재 층:  9
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3, -4] -8
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3]
# 양쪽이 모두 True 입니다!
# 현재 층:  8
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, 3] -4
# 위로 진출 ********************************************************************************************************************************************
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  7
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3]
# 오른쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  8
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, -3] -10
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  9
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, -3, 4] -6
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  10
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4] -2
# 아래층으로
# 왼쪽 방 진입 ----------------------------------------------------------------------
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True], [True, True], [True, False], [True, True], [True, True], [True, False], [True, False], [True, False]]
# 현재 층, start:  11
# 현재 number :  [1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, -4, 1, 1, -1, -1, -1, -3, 3, -3, -3, 4, 4, 4] 2
# 지하 도착
# RecursionErrorTraceback (most recent call last)
# <ipython-input-9-f5d45bf3e6af> in <module>
# ----> 1 solution(numbers, target)
#
# <ipython-input-8-6e32bec17346> in solution(numbers, target)
#       9     count = 0 # target number count
#      10
# ---> 11     dfs(graph, start, visited)
#      12
#      13     print(count)
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      28             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      29             start -= 1
# ---> 30             dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      58             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      59             start -= 1
# ---> 60             dfs(graph, start, visited)
#      61         else:
#      62             print("아래층으로")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      88             print("현재 층, start: ", start)
#      89             print("현재 number : ", number)
# ---> 90             dfs(graph, start, visited)
#      91
#      92     print("모든 경우를 수색했음.")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      61         else:
#      62             print("아래층으로")
# ---> 63             dfs(graph, start, visited)
#      64
#      65     # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      28             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      29             start -= 1
# ---> 30             dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      58             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      59             start -= 1
# ---> 60             dfs(graph, start, visited)
#      61         else:
#      62             print("아래층으로")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      88             print("현재 층, start: ", start)
#      89             print("현재 number : ", number)
# ---> 90             dfs(graph, start, visited)
#      91
#      92     print("모든 경우를 수색했음.")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      88             print("현재 층, start: ", start)
#      89             print("현재 number : ", number)
# ---> 90             dfs(graph, start, visited)
#      91
#      92     print("모든 경우를 수색했음.")
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      61         else:
#      62             print("아래층으로")
# ---> 63             dfs(graph, start, visited)
#      64
#      65     # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
#
# ... last 20 frames repeated, from the frame below ...
#
# <ipython-input-7-e1dd0ffc25b3> in dfs(graph, start, visited)
#      31         else:
#      32             print("아래층으로")
# ---> 33             dfs(graph, start, visited)
#      34
#      35     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
count
# Out:
# 15

# %%
import numpy as np

start = -1 # 시작 노드의 층
number = [] # target number
count = 0 # target number count


def dfs(graph, start, visited, target):
    global number
    global count

    # 아래 층의 왼쪽 방이 False 면 True로 바꾸고, 내려간다.
    if visited[start + 1][0] == False:
        visited[start + 1][0] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][0])
        # 층수를 낮춰준다.
        start += 1

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
            dfs(graph, start, visited, target)
        else:
            dfs(graph, start, visited, target)

    # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
    # 왼쪽만 True고 오른쪽은 False면
    elif visited[start + 1][1] == False:
        visited[start + 1][1] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][1])
        # 층수를 낮춰준다.
        start += 1

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
            dfs(graph, start, visited, target)
        else:
            dfs(graph, start, visited, target)

    # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
    # 올라갈 때는 자기 자신을 초기화하고 올라간다.
    else:

        # 옥상으로 올라갈 수 없을 때는 건물 밖을 나간다.
        if start == -1:
            pass
        else:
            # 위층으로 올라가기 전에 수를 빼준다.
            number.pop()

            # 올라가기 전 해당 층을 초기화 해준다.
            visited[start + 1][0] = False
            visited[start + 1][1] = False

            # 한 층 올라간다.
            start -= 1
            dfs(graph, start, visited, target)

def solution(numbers, target):
    graph = []
    for i in numbers:
        graph.append([i, -i])
    visited = np.zeros((len(graph), 2), dtype=bool).tolist()

    dfs(graph, start, visited, target)

    return count

# %%
solution(numbers, target)
# Out:
# RecursionErrorTraceback (most recent call last)
# <ipython-input-5-f5d45bf3e6af> in <module>
# ----> 1 solution(numbers, target)
#
# <ipython-input-4-1ad736878902> in solution(numbers, target)
#      78     visited = np.zeros((len(graph), 2), dtype=bool).tolist()
#      79
# ---> 80     dfs(graph, start, visited, target)
#      81
#      82     return count
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      27             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      28             start -= 1
# ---> 29             dfs(graph, start, visited, target)
#      30         else:
#      31             dfs(graph, start, visited, target)
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      49             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      50             start -= 1
# ---> 51             dfs(graph, start, visited, target)
#      52         else:
#      53             dfs(graph, start, visited, target)
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      70             # 한 층 올라간다.
#      71             start -= 1
# ---> 72             dfs(graph, start, visited, target)
#      73
#      74 def solution(numbers, target):
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      51             dfs(graph, start, visited, target)
#      52         else:
# ---> 53             dfs(graph, start, visited, target)
#      54
#      55     # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      27             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      28             start -= 1
# ---> 29             dfs(graph, start, visited, target)
#      30         else:
#      31             dfs(graph, start, visited, target)
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      49             number.pop() # 위층으로 올라가기 전에 수를 빼준다.
#      50             start -= 1
# ---> 51             dfs(graph, start, visited, target)
#      52         else:
#      53             dfs(graph, start, visited, target)
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      70             # 한 층 올라간다.
#      71             start -= 1
# ---> 72             dfs(graph, start, visited, target)
#      73
#      74 def solution(numbers, target):
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      70             # 한 층 올라간다.
#      71             start -= 1
# ---> 72             dfs(graph, start, visited, target)
#      73
#      74 def solution(numbers, target):
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      51             dfs(graph, start, visited, target)
#      52         else:
# ---> 53             dfs(graph, start, visited, target)
#      54
#      55     # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
#
# ... last 20 frames repeated, from the frame below ...
#
# <ipython-input-4-1ad736878902> in dfs(graph, start, visited, target)
#      29             dfs(graph, start, visited, target)
#      30         else:
# ---> 31             dfs(graph, start, visited, target)
#      32
#      33     # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %% [markdown]
# ### 뉴 아이디어

# %% [markdown]
# 재귀함수가 맥스에 걸려서 안된다. 그러면 while문으로 해야 하나?! 그러면 시간초과 뜰 거 같은데...

# %%
numbers = [1, 1, 1, 1, 1]
target = 3

# %%
graph = []
for i in numbers:
    graph.append([i, -i])
visited = np.zeros((len(graph), 2), dtype=bool).tolist()

number = []
count = 0
start = -1

while True:
    print("-"*100)
    # 아래 층의 왼쪽 방이 False 면 True로 바꾸고, 내려간다.
    if visited[start + 1][0] == False:
        visited[start + 1][0] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][0])
        # 층수를 낮춰준다.
        start += 1

        print("왼쪽 방 진입", "◁")
        print("방문 이력, visited: ", visited)
        print("현재 층, start: ", start)
        print("현재 number : ", number, np.sum(number))

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            print("최저층입니다. □")
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1
                print("모두 수색 완료, count는?: ", count)

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
        else:
            print("아래층으로", "▼")

    # 1-2 왼쪽 게 True면 오른쪽을 점검한다.
    # 왼쪽만 True고 오른쪽은 False면
    elif visited[start + 1][1] == False:
        visited[start + 1][1] = True
        # True로 바꿀 때마다 더해준다.
        number.append(graph[start + 1][1])
        # 층수를 낮춰준다.
        start += 1

        print("오른쪽 방 진입", "▷")
        print("방문 이력, visited: ", visited)
        print("현재 층, start: ", start)
        print("현재 number : ", number, np.sum(number))

        # 지하로 내려갈 수 없을 때는 옆방을 체크하러 간다.
        if start == len(graph) - 1:
            print("최저층입니다. □")
            # 지하에 닿았다는 것은 그 경우의 끝까지 간 것을 의미
            # count를 계산해준다.
            if np.sum(number) == target:
                count += 1
                print("모두 수색 완료, count는?: ", count)

            number.pop() # 위층으로 올라가기 전에 수를 빼준다.
            start -= 1
        else:
            print("아래층으로", "▼")

    # 둘 다 True면 이미 밑을 다 썼다는 것으로 위로 올라간다.
    # 올라갈 때는 자기 자신을 초기화하고 올라간다.
    else:
        print("양쪽이 모두 True 입니다!")
        print("현재 층: ", start)
        print("현재 이력: ", visited)
        print("현재 number : ", number, np.sum(number))

        # 옥상으로 올라갈 수 없을 때는 건물 밖을 나간다.
        if start == -1:
            print("옥상입니다. ■")
            break
        else:
            # 위층으로 올라가기 전에 수를 빼준다.
            number.pop()

            # 올라가기 전 해당 층을 초기화 해준다.
            visited[start + 1][0] = False
            visited[start + 1][1] = False

            # 한 층 올라간다.
            start -= 1
            print("위로 진출", "▲")
            print("현재 이력, visited: ", visited)
            print("현재 층, start: ", start)
            print("현재 number : ", number)

print("모든 경우를 수색했음.")
print(count)
# Out:
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [1] 1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, 1] 2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, 1] 3
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, 1, 1, 1] 4
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, 1, 1, 1, 1] 5
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, 1, 1, 1, -1] 3
# 최저층입니다. □
# 모두 수색 완료, count는?:  1
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, False], [True, False], [True, False], [True, True]]
# 현재 number :  [1, 1, 1, 1] 4
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, 1, 1, -1] 2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, 1, 1, -1, 1] 3
# 최저층입니다. □
# 모두 수색 완료, count는?:  2
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, False], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, 1, 1, -1, -1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, False], [True, False], [True, True], [True, True]]
# 현재 number :  [1, 1, 1, -1] 2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, False], [True, False], [True, False], [True, True], [False, False]]
# 현재 number :  [1, 1, 1] 3
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, -1] 1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, 1, -1, 1] 2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, 1, -1, 1, 1] 3
# 최저층입니다. □
# 모두 수색 완료, count는?:  3
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, 1, -1, 1, -1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, False], [True, True], [True, False], [True, True]]
# 현재 number :  [1, 1, -1, 1] 2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, 1, -1, -1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, 1, -1, -1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, 1, -1, -1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [True, True]]
# 현재 number :  [1, 1, -1, -1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, 1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, False], [True, False], [True, True], [True, True], [False, False]]
# 현재 number :  [1, 1, -1] 1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  1
# 현재 이력:  [[True, False], [True, False], [True, True], [False, False], [False, False]]
# 현재 number :  [1, 1] 2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, -1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, 1] 1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, -1, 1, 1] 2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, -1, 1, 1, 1] 3
# 최저층입니다. □
# 모두 수색 완료, count는?:  4
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, -1, 1, 1, -1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, True], [True, False], [True, False], [True, True]]
# 현재 number :  [1, -1, 1, 1] 2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, -1, 1, -1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, -1, 1, -1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, False], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, -1, 1, -1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, True], [True, False], [True, True], [True, True]]
# 현재 number :  [1, -1, 1, -1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, False], [True, True], [True, False], [True, True], [False, False]]
# 현재 number :  [1, -1, 1] 1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, -1] -1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, -1, -1, 1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, -1, -1, 1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, -1, -1, 1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, True], [True, True], [True, False], [True, True]]
# 현재 number :  [1, -1, -1, 1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [1, -1, -1, -1] -2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [1, -1, -1, -1, 1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, False], [True, True], [True, True], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [1, -1, -1, -1, -1] -3
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, False], [True, True], [True, True], [True, True], [True, True]]
# 현재 number :  [1, -1, -1, -1] -2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [1, -1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, False], [True, True], [True, True], [True, True], [False, False]]
# 현재 number :  [1, -1, -1] -1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  1
# 현재 이력:  [[True, False], [True, True], [True, True], [False, False], [False, False]]
# 현재 number :  [1, -1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  0
# 현재 이력:  [[True, False], [True, True], [False, False], [False, False], [False, False]]
# 현재 number :  [1] 1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, False], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  -1
# 현재 number :  []
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [-1] -1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, 1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, 1] 1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, 1, 1, 1] 2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, 1, 1, 1] 3
# 최저층입니다. □
# 모두 수색 완료, count는?:  5
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, 1, 1, -1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, False], [True, False], [True, False], [True, True]]
# 현재 number :  [-1, 1, 1, 1] 2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, False], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, 1, 1, -1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, 1, -1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, 1, -1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, False], [True, False], [True, True], [True, True]]
# 현재 number :  [-1, 1, 1, -1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, True], [True, False], [True, False], [True, True], [False, False]]
# 현재 number :  [-1, 1, 1] 1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, -1] -1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, 1, -1, 1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, -1, 1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, -1, 1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, False], [True, True], [True, False], [True, True]]
# 현재 number :  [-1, 1, -1, 1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, True], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, 1, -1, -1] -2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, -1, -1, 1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, 1, -1, -1, -1] -3
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, False], [True, True], [True, True], [True, True]]
# 현재 number :  [-1, 1, -1, -1] -2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, 1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, True], [True, False], [True, True], [True, True], [False, False]]
# 현재 number :  [-1, 1, -1] -1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  1
# 현재 이력:  [[True, True], [True, False], [True, True], [False, False], [False, False]]
# 현재 number :  [-1, 1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [-1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, -1] -2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, 1] -1
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, -1, 1, 1] 0
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, 1, 1, 1] 1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, 1, 1, -1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, True], [True, False], [True, False], [True, True]]
# 현재 number :  [-1, -1, 1, 1] 0
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, False], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, 1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, -1, 1, -1] -2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, 1, -1, 1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, False], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, 1, -1, -1] -3
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, True], [True, False], [True, True], [True, True]]
# 현재 number :  [-1, -1, 1, -1] -2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, 1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, True], [True, True], [True, False], [True, True], [False, False]]
# 현재 number :  [-1, -1, 1] -1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, False], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, -1] -3
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, -1, -1, 1] -2
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, False], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, -1, 1, 1] -1
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, False], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, -1, 1, -1] -3
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, True], [True, True], [True, False], [True, True]]
# 현재 number :  [-1, -1, -1, 1] -2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, True], [True, False], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, -1]
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  3
# 현재 number :  [-1, -1, -1, -1] -4
# 아래층으로 ▼
# ----------------------------------------------------------------------------------------------------
# 왼쪽 방 진입 ◁
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, True], [True, False]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, -1, -1, 1] -3
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 오른쪽 방 진입 ▷
# 방문 이력, visited:  [[True, True], [True, True], [True, True], [True, True], [True, True]]
# 현재 층, start:  4
# 현재 number :  [-1, -1, -1, -1, -1] -5
# 최저층입니다. □
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  3
# 현재 이력:  [[True, True], [True, True], [True, True], [True, True], [True, True]]
# 현재 number :  [-1, -1, -1, -1] -4
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 층, start:  2
# 현재 number :  [-1, -1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  2
# 현재 이력:  [[True, True], [True, True], [True, True], [True, True], [False, False]]
# 현재 number :  [-1, -1, -1] -3
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [True, True], [False, False], [False, False]]
# 현재 층, start:  1
# 현재 number :  [-1, -1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  1
# 현재 이력:  [[True, True], [True, True], [True, True], [False, False], [False, False]]
# 현재 number :  [-1, -1] -2
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [True, True], [False, False], [False, False], [False, False]]
# 현재 층, start:  0
# 현재 number :  [-1]
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  0
# 현재 이력:  [[True, True], [True, True], [False, False], [False, False], [False, False]]
# 현재 number :  [-1] -1
# 위로 진출 ▲
# 현재 이력, visited:  [[True, True], [False, False], [False, False], [False, False], [False, False]]
# 현재 층, start:  -1
# 현재 number :  []
# ----------------------------------------------------------------------------------------------------
# 양쪽이 모두 True 입니다!
# 현재 층:  -1
# 현재 이력:  [[True, True], [False, False], [False, False], [False, False], [False, False]]
# 현재 number :  [] 0.0
# 옥상입니다. ■
# 모든 경우를 수색했음.
# 5

# %%
count
# Out:
# 5
